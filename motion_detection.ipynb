# %%
# pip install opencv-python numpy

# %%
import os
import cv2
import numpy as np
import subprocess
import tempfile
import logging
import time

# BUFFER_DIR = "/home/piuser/videos/buffer"
BUFFER_DIR = "./buffer/buffer_test"
BUFFER_DIR = "S:\\Dev\\rpi-surveillence\\buffer\\buffer_test"
TMP_DIR = "./buffer/buffer_tmp"
# BUFFER_DIR = "./buffer"
# LOG_FILE = "/home/piuser/videos/logs/motion_detect.log"
FRAMES_TO_SAMPLE = 5
SLEEP_INTERVAL=2
PIXEL_THRESHOLD=10
CHANGE_RATIO=0.001
FLUSH_N_CLIPS = 32 # if you have more than this many clips in a row with motion, flush them out into another clip even if you'll cut up the motion. 

CLIP_DURATION = 10.0
CLIP_FPS = 30
CLIP_FRAME_SPEED = 0.0339

LQ_WIDTH, LQ_HEIGHT = 160, 90  # resize early in ffmpeg

# CLIP_DIR = "/buffer/clips_test"
CLIP_DIR = "S:\\Dev\\rpi-surveillence\\buffer\\clips_test"
os.makedirs(CLIP_DIR, exist_ok=True)
os.makedirs(BUFFER_DIR, exist_ok=True)
os.makedirs(TMP_DIR, exist_ok=True)
# os.makedirs(os.path.dirname(LOG_FILE), exist_ok=True)

# %%
logging.basicConfig(level=logging.DEBUG,
                    format="%(asctime)s [%(levelname)s] %(message)s",
                    handlers=[
                        # logging.FileHandler(LOG_FILE),
                        logging.StreamHandler()  # ensures output appears in journalctl/systemd logs
                    ])
logging.debug("test")
# Out:
# 2025-10-15 01:02:49,127 [DEBUG] test

# %%
# def extract_sample_frames(input_path):
#     """Rewrap .h264 to .mp4 and extract 5 sample frames as np.array list."""
#     with tempfile.TemporaryDirectory() as tmpdir:
#         logging.debug("extracting sample frames")
#         temp_mp4 = os.path.join(tmpdir, "temp.mp4")

#         # Step 1: Rewrap to MP4 (no re-encode)
#         cmd_wrap = ["ffmpeg", "-hide_banner", "-loglevel", "error",
#                     "-f", "h264", "-i", input_path, "-c", "copy", "-y", temp_mp4]
#         subprocess.run(cmd_wrap, check=True)

#         # Step 2: Determine duration (seconds)
#         result = subprocess.run(
#             ["ffprobe", "-v", "error", "-show_entries", "format=duration",
#              "-of", "default=noprint_wrappers=1:nokey=1", temp_mp4],
#             capture_output=True, text=True
#         )
#         try:
#             duration = float(result.stdout.strip())
#         except ValueError:
#             logging.warning(f"Could not read duration for {input_path}")
#             return []

#         # Step 3: Extract sample frames
#         sample_times = np.linspace(0, duration, FRAMES_TO_SAMPLE, endpoint=False)
#         frames = []

#         for i, t in enumerate(sample_times):
#             frame_path = os.path.join(tmpdir, f"frame_{i}.jpg")
#             cmd = ["ffmpeg", "-hide_banner", "-loglevel", "error",
#                    "-ss", str(t), "-i", temp_mp4, "-frames:v", "1",
#                    "-q:v", "4", "-y", frame_path]
#             subprocess.run(cmd, check=True)

#             frame = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)
#             if frame is not None:
#                 frames.append(frame)

#         return frames

# def extract_sample_frames(input_path):
#     """Efficiently extract sample frames directly from .h264 via ffmpeg pipe."""
#     logging.debug(f"Extracting sample frames (optimized) from {input_path}")
#     with tempfile.TemporaryDirectory() as tmpdir:
#     # tmpdir = "S:\\Dev\\rpi-surveillence\\buffer\\buffer_tmp"


#         # Build select filter to pick N evenly spaced times
#         select_expr = "+".join([
#             f"gte(t,{t:.4f})*lt(t,{t+CLIP_FRAME_SPEED:.4f})"
#             for t in np.linspace(0, CLIP_DURATION, FRAMES_TO_SAMPLE, endpoint=False)
#         ])
#         vf_filter = f"select='{select_expr}',scale={LQ_WIDTH}:{LQ_HEIGHT},format=gray"

#         output_pattern = os.path.join(tmpdir, "frame_%03d.jpg")
#         cmd = [
#             "ffmpeg", "-hide_banner", "-loglevel", "error",
#             "-i", input_path,
#             "-vf", vf_filter,
#             "-vsync", "vfr",
#             "-q:v", "4",              # JPEG quality
#             "-y", output_pattern
#         ]

#         logging.debug(cmd)

#         subprocess.run(cmd, check=True)

#         # Read frames back into memory
#         frames = []
#         for i in range(FRAMES_TO_SAMPLE):
#             path = os.path.join(tmpdir, f"frame_{i+1:03d}.jpg")  # ffmpeg starts at 1
#             if not os.path.exists(path):
#                 continue
#             frame = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
#             if frame is not None:
#                 frames.append(frame)

#         return frames
def extract_sample_frames(input_path):
    """Efficiently extract sample frames directly from .h264 via ffmpeg pipe."""
    logging.debug(f"Extracting sample frames (optimized) from {input_path}")
    with tempfile.TemporaryDirectory() as tmpdir:
    # tmpdir = "S:\\Dev\\rpi-surveillence\\buffer\\buffer_tmp"
        vf_filter = f"scale={LQ_WIDTH}:{LQ_HEIGHT},format=gray"
        output_pattern = os.path.join(tmpdir, "frame_%03d.jpg")
        cmd = [
            "ffmpeg", "-hide_banner", "-loglevel", "error",
            "-i", input_path,
            "-skip_frame", "nokey", # efficiently extract just the keyframes
            "-vf", vf_filter,
            "-vsync", "vfr",
            "-q:v", "4",              # JPEG quality
            "-y", output_pattern
        ]

        # logging.debug(cmd)

        subprocess.run(cmd, check=True)

        # Read frames back into memory
        frames = []
        for file in os.listdir(tmpdir):
            path = os.path.join(tmpdir, file)
            frame = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            if frame is not None:
                frames.append(frame)
        logging.debug(f"generated/read {len(frames)} frames")
        return frames

len(extract_sample_frames("S:\\Dev\\rpi-surveillence\\buffer\\buffer_test2\\segment_00021.h264"))
# Out:
# 2025-10-15 01:02:49,146 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test2\segment_00021.h264
# 2025-10-15 01:02:49,599 [DEBUG] generated/read 300 frames
# 300

# %%
# def detect_motion(frames): # keeping this here for reference
#     """Return True if frame-to-frame difference exceeds threshold."""
#     # logging.debug("detecting motion")
#     if len(frames) < 2:
#         return False

#     frames = [cv2.GaussianBlur(cv2.resize(f, (0,0), fx=0.25, fy=0.25), (5,5), 0) for f in frames]

#     diffs = []
#     for a, b in zip(frames, frames[1:]):
#         diff = cv2.absdiff(a, b)
#         diffs.append(np.sum(diff))
#     avg_diff = np.mean(diffs)
#     logging.info(f"motion diff: {avg_diff:,}")
#     return avg_diff > MOTION_THRESHOLD

def detect_motion(frames, pixel_thresh=PIXEL_THRESHOLD, change_ratio=CHANGE_RATIO):
    """
    Detect motion based on % of pixels with large changes between frames.
    pixel_thresh: difference value (0–255) for pixel to count as 'changed'
    change_ratio: fraction of changed pixels needed to trigger motion
    """
    logging.debug("detecting motion on frames")
    if len(frames) < 2:
        logging.warning(f"not enough frames, only {len(frames)} of them")
        return False
    
    # frames = [cv2.resize(f, (0,0), fx=0.25, fy=0.25) for f in frames]
    frames = [cv2.GaussianBlur(f, (5,5), 0) for f in frames]

    total_pixels = frames[0].size
    ratios = []

    for a, b in zip(frames, frames[1:]):
        diff = cv2.absdiff(a, b)
        motion_mask = diff > pixel_thresh
        ratio = np.count_nonzero(motion_mask) / total_pixels
        ratios.append(ratio)

    avg_ratio = np.mean(ratios)
    logging.info(f"motion pixel ratio: {avg_ratio:.6f}")
    return avg_ratio > change_ratio

# %%
# def process_file(file_path):
#     base = os.path.basename(file_path)
#     # logging.info(f"Processing {base}")

#     try:
#         frames = extract_sample_frames(file_path)
#         if not frames:
#             logging.warning(f"No frames extracted from {base}")
#             return

#         if detect_motion(frames):
#             logging.info(f"Motion detected in {base}")
#             pass
#         else:
#             logging.info(f"No motion in {base}")
#     except subprocess.CalledProcessError:
#         logging.error(f"FFmpeg failed on {base}")
#     except Exception as e:
#         logging.exception(f"Error processing {base}: {e}")

# %%
# for i,filename in enumerate(sorted(os.listdir(BUFFER_DIR))):
#     if filename.lower().endswith(".h264"):
#         path = os.path.join(BUFFER_DIR, filename)
#         logging.info(path)
#         process_file(path)
#     if i > 20:
#         break

# %% [markdown]
# 2025-10-13 22:24:42,233 [INFO] ./buffer\test_lots_of_movement.h264
# 2025-10-13 22:24:42,936 [INFO] motion diff: 41,581,065.25
# 2025-10-13 22:24:42,937 [INFO] ./buffer\test_lots_of_movement_2.h264
# 2025-10-13 22:24:43,608 [INFO] motion diff: 41,247,821.5
# 2025-10-13 22:24:43,609 [INFO] ./buffer\test_lots_of_movement_3.h264
# 2025-10-13 22:24:44,294 [INFO] motion diff: 30,238,706.5
# 2025-10-13 22:24:44,295 [INFO] ./buffer\test_no_movement.h264
# 2025-10-13 22:24:44,846 [INFO] motion diff: 5,648,562.0
# 2025-10-13 22:24:44,846 [INFO] ./buffer\test_no_movement_2.h264
# 2025-10-13 22:24:45,478 [INFO] motion diff: 4,253,197.5
# 2025-10-13 22:24:45,479 [INFO] ./buffer\test_really_small_movement.h264
# 2025-10-13 22:24:46,109 [INFO] motion diff: 3,235,704.25
# 2025-10-13 22:24:46,110 [INFO] ./buffer\test_really_small_movement_2.h264
# 2025-10-13 22:24:46,753 [INFO] motion diff: 3,658,631.0
# 2025-10-13 22:24:46,754 [INFO] ./buffer\test_small_movement.h264
# 2025-10-13 22:24:47,409 [INFO] motion diff: 33,363,687.5
# 2025-10-13 22:24:47,410 [INFO] ./buffer\test_small_movement_2.h264
# 2025-10-13 22:24:48,121 [INFO] motion diff: 3,993,828.0
# 2025-10-13 22:24:48,122 [INFO] ./buffer\test_small_movement_3.h264
# 2025-10-13 22:24:48,778 [INFO] motion diff: 3,481,125.0
# 2025-10-13 22:24:48,779 [INFO] ./buffer\test_small_movement_4.h264
# 2025-10-13 22:24:49,428 [INFO] motion diff: 5,774,211.0
# 2025-10-13 22:24:49,430 [INFO] ./buffer\test_tons_of_movement.h264
# 2025-10-13 22:24:50,041 [INFO] motion diff: 73,623,610.5

# %%
# === Save clip ===
def save_clip(segments):
    """Concatenate motion segments into a single mp4 clip."""
    if not segments:
        return
    first_clip_number = os.path.basename(segments[0]).replace('segment_', '').replace('.h264','')
    clip_file_extension = ".mp4"
    clip_name = f"clip_{first_clip_number}"
    iter_num = 1 # doesn't overwrite files when the device resets.
    while (os.path.exists(os.path.join(CLIP_DIR, clip_name+f"_{iter_num}"+clip_file_extension))):
        iter_num += 1
    clip_name = clip_name+f"_{iter_num}"+clip_file_extension
    clip_path = os.path.join(CLIP_DIR, clip_name)

    try:
        with open(os.path.join(TMP_DIR, "segments.txt"), "w") as f:
            for s in segments:
                f.write(f"file '{s}'\n")

        logging.info(f"Creating clip from {len(segments)} segments → {clip_path}")

        result = subprocess.run([
            "ffmpeg", "-f", "concat", "-safe", "0",
            "-i", os.path.join(TMP_DIR, "segments.txt"), "-c", "copy",
            clip_path, "-y"
        ], capture_output=True, text=True)

        if result.returncode == 0:
            logging.info(f"✅ Saved clip: {clip_path}")
            for s in segments:
                os.remove(s)
                logging.debug(f"Deleted processed segment: {s}")
        else:
            logging.error(f"FFmpeg failed: {result.stderr}")

    except Exception as e:
        logging.exception(f"Error while saving clip: {e}")

# %%
motion_group = []
processed_segments = set()

while True:
    try:
        segments = sorted(os.listdir(BUFFER_DIR)) #assumes a sortable order
        # Skip already processed
        segments = [s for s in segments if s not in processed_segments]
        if not segments:
            logging.debug("no available segments to process, sleeping")
            time.sleep(SLEEP_INTERVAL)
            continue

        for i, seg in enumerate(segments):
            logging.debug(f"processing segment #{i}, {seg}")
            seg_path = os.path.join(BUFFER_DIR, seg)
            # Always skip last one (may still be writing)
            if i == len(segments) - 1:
                logging.debug("reached the end of the segments")
                time.sleep(0.1)
                break

            frames = extract_sample_frames(seg_path)
            motion = detect_motion(frames)
            if motion:
                logging.debug(f"Adding segment #{i}, {seg} to the motion group")
                motion_group.append(seg_path)
                if len(motion_group) > FLUSH_N_CLIPS:
                    logging.debug(f"Flushing all current motion group segments to a clip despite motion being detected")
                    save_clip(motion_group)
                    motion_group = [seg_path] #note that this prioritizes cohesive video viewing over later recompilation into one big video. Think about changing later todo
            else:
                if motion_group:
                    logging.debug(f"saving all current motion group segments to a clip")
                    save_clip(motion_group)
                    motion_group = []
                os.remove(seg_path)
                logging.debug(f"Removed non-motion segment: {seg_path}")

            processed_segments.add(seg)
            time.sleep(0.1)
        time.sleep(SLEEP_INTERVAL)

    except Exception as e:
        logging.exception(f"Main loop error: {e}")
        time.sleep(SLEEP_INTERVAL)
# Out:
# 2025-10-15 01:02:49,743 [DEBUG] processing segment #0, segment_00000.h264
# 2025-10-15 01:02:49,744 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00000.h264
# 2025-10-15 01:02:50,052 [DEBUG] generated/read 143 frames
# 2025-10-15 01:02:50,088 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:50,093 [INFO] motion pixel ratio: 0.020115
# 2025-10-15 01:02:50,094 [DEBUG] Adding segment #0, segment_00000.h264 to the motion group
# 2025-10-15 01:02:50,203 [DEBUG] processing segment #1, segment_00001.h264
# 2025-10-15 01:02:50,203 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00001.h264
# 2025-10-15 01:02:50,681 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:50,748 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:50,756 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:02:50,756 [DEBUG] saving all current motion group segments to a clip
# 2025-10-15 01:02:50,758 [INFO] Creating clip from 1 segments → S:\Dev\rpi-surveillence\buffer\clips_test\clip_00000_13.mp4
# 2025-10-15 01:02:50,895 [INFO] ✅ Saved clip: S:\Dev\rpi-surveillence\buffer\clips_test\clip_00000_13.mp4
# 2025-10-15 01:02:50,896 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00000.h264
# 2025-10-15 01:02:50,898 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00001.h264
# 2025-10-15 01:02:51,010 [DEBUG] processing segment #2, segment_00002.h264
# 2025-10-15 01:02:51,010 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00002.h264
# 2025-10-15 01:02:51,435 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:51,499 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:51,506 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:02:51,508 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00002.h264
# 2025-10-15 01:02:51,613 [DEBUG] processing segment #3, segment_00003.h264
# 2025-10-15 01:02:51,614 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00003.h264
# 2025-10-15 01:02:52,130 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:52,195 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:52,202 [INFO] motion pixel ratio: 0.045546
# 2025-10-15 01:02:52,203 [DEBUG] Adding segment #3, segment_00003.h264 to the motion group
# 2025-10-15 01:02:52,306 [DEBUG] processing segment #4, segment_00004.h264
# 2025-10-15 01:02:52,306 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00004.h264
# 2025-10-15 01:02:52,781 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:52,851 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:52,859 [INFO] motion pixel ratio: 0.024638
# 2025-10-15 01:02:52,860 [DEBUG] Adding segment #4, segment_00004.h264 to the motion group
# 2025-10-15 01:02:52,967 [DEBUG] processing segment #5, segment_00005.h264
# 2025-10-15 01:02:52,967 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00005.h264
# 2025-10-15 01:02:53,406 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:53,470 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:53,478 [INFO] motion pixel ratio: 0.021514
# 2025-10-15 01:02:53,479 [DEBUG] Adding segment #5, segment_00005.h264 to the motion group
# 2025-10-15 01:02:53,587 [DEBUG] processing segment #6, segment_00006.h264
# 2025-10-15 01:02:53,588 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00006.h264
# 2025-10-15 01:02:54,093 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:54,185 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:54,194 [INFO] motion pixel ratio: 0.015177
# 2025-10-15 01:02:54,195 [DEBUG] Adding segment #6, segment_00006.h264 to the motion group
# 2025-10-15 01:02:54,297 [DEBUG] processing segment #7, segment_00007.h264
# 2025-10-15 01:02:54,297 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00007.h264
# 2025-10-15 01:02:54,753 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:56,354 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:56,363 [INFO] motion pixel ratio: 0.001338
# 2025-10-15 01:02:56,364 [DEBUG] Adding segment #7, segment_00007.h264 to the motion group
# 2025-10-15 01:02:56,479 [DEBUG] processing segment #8, segment_00008.h264
# 2025-10-15 01:02:56,479 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00008.h264
# 2025-10-15 01:02:56,902 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:56,971 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:56,978 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:02:56,979 [DEBUG] saving all current motion group segments to a clip
# 2025-10-15 01:02:56,980 [INFO] Creating clip from 5 segments → S:\Dev\rpi-surveillence\buffer\clips_test\clip_00003_13.mp4
# 2025-10-15 01:02:57,349 [INFO] ✅ Saved clip: S:\Dev\rpi-surveillence\buffer\clips_test\clip_00003_13.mp4
# 2025-10-15 01:02:57,351 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00003.h264
# 2025-10-15 01:02:57,352 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00004.h264
# 2025-10-15 01:02:57,354 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00005.h264
# 2025-10-15 01:02:57,355 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00006.h264
# 2025-10-15 01:02:57,356 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00007.h264
# 2025-10-15 01:02:57,358 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00008.h264
# 2025-10-15 01:02:57,468 [DEBUG] processing segment #9, segment_00009.h264
# 2025-10-15 01:02:57,468 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00009.h264
# 2025-10-15 01:02:57,879 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:57,947 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:57,956 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:02:57,958 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00009.h264
# 2025-10-15 01:02:58,074 [DEBUG] processing segment #10, segment_00010.h264
# 2025-10-15 01:02:58,074 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00010.h264
# 2025-10-15 01:02:58,748 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:58,853 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:58,862 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:02:58,864 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00010.h264
# 2025-10-15 01:02:58,973 [DEBUG] processing segment #11, segment_00011.h264
# 2025-10-15 01:02:58,973 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00011.h264
# 2025-10-15 01:02:59,756 [DEBUG] generated/read 300 frames
# 2025-10-15 01:02:59,832 [DEBUG] detecting motion on frames
# 2025-10-15 01:02:59,840 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:02:59,842 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00011.h264
# 2025-10-15 01:02:59,947 [DEBUG] processing segment #12, segment_00012.h264
# 2025-10-15 01:02:59,947 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00012.h264
# 2025-10-15 01:03:00,371 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:01,702 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:01,708 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:01,710 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00012.h264
# 2025-10-15 01:03:01,819 [DEBUG] processing segment #13, segment_00013.h264
# 2025-10-15 01:03:01,819 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00013.h264
# 2025-10-15 01:03:02,218 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:02,341 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:02,350 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:02,352 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00013.h264
# 2025-10-15 01:03:02,461 [DEBUG] processing segment #14, segment_00014.h264
# 2025-10-15 01:03:02,461 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00014.h264
# 2025-10-15 01:03:02,878 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:02,945 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:02,952 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:02,953 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00014.h264
# 2025-10-15 01:03:03,067 [DEBUG] processing segment #15, segment_00015.h264
# 2025-10-15 01:03:03,067 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00015.h264
# 2025-10-15 01:03:03,547 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:03,628 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:03,637 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:03,640 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00015.h264
# 2025-10-15 01:03:03,745 [DEBUG] processing segment #16, segment_00016.h264
# 2025-10-15 01:03:03,746 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00016.h264
# 2025-10-15 01:03:04,159 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:04,222 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:04,229 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:04,230 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00016.h264
# 2025-10-15 01:03:04,333 [DEBUG] processing segment #17, segment_00017.h264
# 2025-10-15 01:03:04,334 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00017.h264
# 2025-10-15 01:03:04,733 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:04,803 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:04,812 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:04,813 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00017.h264
# 2025-10-15 01:03:04,921 [DEBUG] processing segment #18, segment_00018.h264
# 2025-10-15 01:03:04,921 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00018.h264
# 2025-10-15 01:03:05,326 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:06,989 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:06,997 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:06,998 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00018.h264
# 2025-10-15 01:03:07,103 [DEBUG] processing segment #19, segment_00019.h264
# 2025-10-15 01:03:07,104 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00019.h264
# 2025-10-15 01:03:07,504 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:08,581 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:08,591 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:08,593 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00019.h264
# 2025-10-15 01:03:08,697 [DEBUG] processing segment #20, segment_00020.h264
# 2025-10-15 01:03:08,698 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00020.h264
# 2025-10-15 01:03:09,097 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:09,163 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:09,169 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:09,171 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00020.h264
# 2025-10-15 01:03:09,273 [DEBUG] processing segment #21, segment_00021.h264
# 2025-10-15 01:03:09,274 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00021.h264
# 2025-10-15 01:03:09,663 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:09,727 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:09,735 [INFO] motion pixel ratio: 0.018960
# 2025-10-15 01:03:09,735 [DEBUG] Adding segment #21, segment_00021.h264 to the motion group
# 2025-10-15 01:03:09,847 [DEBUG] processing segment #22, segment_00022.h264
# 2025-10-15 01:03:09,847 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00022.h264
# 2025-10-15 01:03:10,386 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:10,495 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:10,505 [INFO] motion pixel ratio: 0.009629
# 2025-10-15 01:03:10,506 [DEBUG] Adding segment #22, segment_00022.h264 to the motion group
# 2025-10-15 01:03:10,621 [DEBUG] processing segment #23, segment_00023.h264
# 2025-10-15 01:03:10,622 [DEBUG] Extracting sample frames (optimized) from S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00023.h264
# 2025-10-15 01:03:11,052 [DEBUG] generated/read 300 frames
# 2025-10-15 01:03:11,116 [DEBUG] detecting motion on frames
# 2025-10-15 01:03:11,124 [INFO] motion pixel ratio: 0.000000
# 2025-10-15 01:03:11,125 [DEBUG] saving all current motion group segments to a clip
# 2025-10-15 01:03:11,125 [INFO] Creating clip from 2 segments → S:\Dev\rpi-surveillence\buffer\clips_test\clip_00021_1.mp4
# 2025-10-15 01:03:11,318 [INFO] ✅ Saved clip: S:\Dev\rpi-surveillence\buffer\clips_test\clip_00021_1.mp4
# 2025-10-15 01:03:11,320 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00021.h264
# 2025-10-15 01:03:11,322 [DEBUG] Deleted processed segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00022.h264
# 2025-10-15 01:03:11,323 [DEBUG] Removed non-motion segment: S:\Dev\rpi-surveillence\buffer\buffer_test\segment_00023.h264
# 2025-10-15 01:03:11,430 [DEBUG] processing segment #24, segment_00024.h264
# 2025-10-15 01:03:11,430 [DEBUG] reached the end of the segments
# 2025-10-15 01:03:13,550 [DEBUG] processing segment #0, segment_00024.h264
# 2025-10-15 01:03:13,550 [DEBUG] reached the end of the segments
# 2025-10-15 01:03:15,673 [DEBUG] processing segment #0, segment_00024.h264
# 2025-10-15 01:03:15,673 [DEBUG] reached the end of the segments
# 2025-10-15 01:03:17,796 [DEBUG] processing segment #0, segment_00024.h264
# 2025-10-15 01:03:17,796 [DEBUG] reached the end of the segments
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 42
#      40         processed_segments.add(seg)
#      41         time.sleep(0.1)
# ---> 42     time.sleep(SLEEP_INTERVAL)
#      44 except Exception as e:
#      45     logging.exception(f"Main loop error: {e}")
#
# KeyboardInterrupt:

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
## setup for test
import shutil
import os
source_dir = "S:\\Dev\\rpi-surveillence\\buffer\\buffer_test2"

destination_dir = "S:\\Dev\\rpi-surveillence\\buffer\\buffer_test"
# Copy the entire directory tree

shutil.rmtree(destination_dir)
shutil.copytree(source_dir, destination_dir)
print("Directory copied successfully.")
# Out:
# Directory copied successfully.
